# %% [markdown]
# # Simulation of background phonon radiation in a low temperature system

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as c


T = 3 #K

w = np.linspace(1e-3,1e3)
n = 1/(np.exp(c.hbar*w/(c.k*T))-1)

plt.plot(w,n)
# Out:
# <ipython-input-3-a28e493fc1fc>:9: RuntimeWarning: divide by zero encountered in true_divide
#   n = 1/(np.exp(c.hbar*w/(c.k*T))-1)
